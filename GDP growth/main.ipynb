# %%
import pandas as pd

# %%
main = pd.read_csv('GDP growth.csv')

# %%
main
# Out:
#                     Country Name Country Code         Indicator Name  \
# 0                          Aruba          ABW  GDP growth (annual %)
# 1    Africa Eastern and Southern          AFE  GDP growth (annual %)
# 2                    Afghanistan          AFG  GDP growth (annual %)
# 3     Africa Western and Central          AFW  GDP growth (annual %)
# 4                         Angola          AGO  GDP growth (annual %)
# ..                           ...          ...                    ...
# 260                       Kosovo          XKX  GDP growth (annual %)
# 261                  Yemen, Rep.          YEM  GDP growth (annual %)
# 262                 South Africa          ZAF  GDP growth (annual %)
# 263                       Zambia          ZMB  GDP growth (annual %)
# 264                     Zimbabwe          ZWE  GDP growth (annual %)
#
#         Indicator Code      2000      2001       2002       2003       2004  \
# ...

# %%
metadata_country = pd.read_csv('Metadata_Country_API_NY.GDP.MKTP.KD.ZG_DS2_en_csv_v2_31631.csv')

# %%
metadata_country.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
main['Country Name'].nunique()
# Out:
# 265

# %%
main.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code'], axis=1, inplace=True)
# Menggunakan pd.melt untuk mengubah kolom-kolom tahun menjadi baris
df_melt = pd.melt(main, id_vars=['Country Name'],
                  value_vars=['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
                              '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
                              '2018', '2019', '2020', '2021', '2022', '2023'], 
                  var_name='Year', value_name='Value')

# %%
df_melt.to_csv('GDP_melt.csv', index=False)
