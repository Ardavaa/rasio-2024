# %%
import pandas as pd

# %%
main = pd.read_csv('unemployment.csv')

# %%
main
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 260                       Kosovo          XKX
# 261                  Yemen, Rep.          YEM
# 262                 South Africa          ZAF
# 263                       Zambia          ZMB
# 264                     Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  \
# 0    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 1    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 2    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 3    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# ...

# %%
main.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')

# %%
main.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code'], axis=1, inplace=True)
# Menggunakan pd.melt untuk mengubah kolom-kolom tahun menjadi baris
df_melt = pd.melt(main, id_vars=['Country Name'],
                  value_vars=['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
                              '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
                              '2018', '2019', '2020', '2021', '2022', '2023'], 
                  var_name='Year', value_name='Value')

# %%
main['Country Name'].nunique()
# Out:
# 265

# %%
df_melt
# Out:
#                      Country Name  Year      Value
# 0                           Aruba  2000        NaN
# 1     Africa Eastern and Southern  2000   7.409352
# 2                     Afghanistan  2000   7.955000
# 3      Africa Western and Central  2000   4.627660
# 4                          Angola  2000  16.502000
# ...                           ...   ...        ...
# 6355                       Kosovo  2023        NaN
# 6356                  Yemen, Rep.  2023  17.215000
# 6357                 South Africa  2023  27.988000
# 6358                       Zambia  2023   5.913000
# 6359                     Zimbabwe  2023   8.759000
#
# [6360 rows x 3 columns]

# %%
df_melt.to_csv('unemployment_melt.csv', index=False)
